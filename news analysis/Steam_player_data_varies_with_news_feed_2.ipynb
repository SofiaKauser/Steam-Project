# %% [markdown]
# # This time: with all the data.

# %%
path = "Resources/Valve_Player_Data.csv"

import matplotlib.pyplot as plt
import pandas as pd
import requests
import numpy as np
from pprint import pprint
import time
import datetime
from dateutil.relativedelta import relativedelta

# %%
monthly_players = pd.read_csv(path)
monthly_players
# Out:
#           Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0     September 2021    512350.92     268.96       +0.05%        942519
# 1        August 2021    512081.96    6014.60       +1.19%        802544
# 2          July 2021    506067.36  -43279.72       -7.88%        763523
# 3          June 2021    549347.08 -110541.81      -16.75%        929940
# 4           May 2021    659888.89  -63457.63       -8.77%       1087197
# ...              ...          ...        ...          ...           ...
# 5266   December 2016       192.03     -21.90      -10.24%           405
# 5267   November 2016       213.92    -134.68      -38.63%           537
# 5268    October 2016       348.60    -201.75      -36.66%          1031
# 5269  September 2016       550.36     543.26    +7654.89%          2836
# 5270     August 2016         7.10        NaN          NaN            18
#
#                                      URL        Date  \
# 0        https://steamcharts.com/app/730  2021-09-01
# 1        https://steamcharts.com/app/730  2021-08-01
# 2        https://steamcharts.com/app/730  2021-07-01
# 3        https://steamcharts.com/app/730  2021-06-01
# 4        https://steamcharts.com/app/730  2021-05-01
# ...                                  ...         ...
# 5266  https://steamcharts.com/app/435150  2016-12-01
# 5267  https://steamcharts.com/app/435150  2016-11-01
# 5268  https://steamcharts.com/app/435150  2016-10-01
# 5269  https://steamcharts.com/app/435150  2016-09-01
# 5270  https://steamcharts.com/app/435150  2016-08-01
#
#                              Game_Name
# 0     Counter Strike: Global Offensive
# 1     Counter Strike: Global Offensive
# 2     Counter Strike: Global Offensive
# 3     Counter Strike: Global Offensive
# 4     Counter Strike: Global Offensive
# ...                                ...
# 5266          Divinity: Original Sin 2
# 5267          Divinity: Original Sin 2
# 5268          Divinity: Original Sin 2
# 5269          Divinity: Original Sin 2
# 5270          Divinity: Original Sin 2
#
# [5271 rows x 8 columns]

# %%
monthly_players.nunique()
# Out:
# Month_Year       111
# Avg_players     5241
# Gain            5135
# Percent_Gain    3685
# Peak_Players    4988
# URL               98
# Date             111
# Game_Name         98
# dtype: int64

# %%
monthly_players.dtypes
# Out:
# Month_Year       object
# Avg_players     float64
# Gain            float64
# Percent_Gain     object
# Peak_Players      int64
# URL              object
# Date             object
# Game_Name        object
# dtype: object

# %%
# EXTRACT AND TRANSFORM DATA

# drop first two months for every game as these extreme values will totally skew the data.

# %%
monthly_players.Game_Name.unique()
# Out:
# array(['Counter Strike: Global Offensive', 'Dota 2',
#        'PUBG: Battlegrounds', 'Apex Legends', 'Team Fortress 2',
#        'Grand Theft Auto V', 'NARAKA: BLADEPOINT', 'Wallpaper Engine',
#        'Rust', 'Destiny 2', 'Warframe', 'Cookie Clicker',
#        "Tom Clancy's Rainbow Six Seige", 'Football Manager 2021 ',
#        'PAYDAY 2', 'ARK: Survival Evolved', 'Dead by Daylight',
#        "Sid Meier's Civilization VI", 'MIR4', 'Unturned', 'Terraria',
#        'War Thunder', 'Hearts of Iron IV', 'Battlefield V', 'Valheim',
#        'World of Tanks Blitz', 'Dayz', 'Total War: WARHAMMER II',
#        "Don't Starve Together", 'Euro Truck Simulator 2', 'Rocket League',
#        "Garry's Mod", 'Monster Hunter: World', 'Stardew Valley',
#        'FINAL FANTASY XIV Online', 'Bless Unleashed ',
#        'The Witcher 3: Wild Hunt', '雀魂麻将(MahjongSoul)', 'RimWorld',
#        'Red Dead Redemption 2', '7 Days to Die', 'Black Desert',
#        'Cities: Skylines', "Sid Meier's Civilization V",
#        'Farming Simulator 19',
#        'The Elder Scrolls V: Skyrim Special Edition', 'Stellaris',
#        'The Elder Scrolls Online', 'Left 4 Dead 2', 'Forza Horizion 4',
#        'Europa Universalis IV', 'Spacewar',
#        'Age of Empires II: Definitive Edition',
#        'Pathfinder: Wrath of Righteous', 'Yu-Gi-Oh! Duel Links',
#        'The Binding of Isaac: Rebirth', 'SCUM', 'Fallout 4', 'Factorio',
#        'Mount & Blade II: Bannerlord ', 'tModLoader', 'NBA 2k22',
#        'Bloons TD 6', 'Brawlhalla', 'VRChat',
#        'Fall Guys: Ultimate Knockout', 'Arma 3', 'Football Manager 2020',
#        'World of Warships', 'EA SPORTS FIFA 21', 'DARK SOULS III',
#        'Crusader Kings III', "Conqueror's Blade", "No Man's Sky",
#        'eFootball PES 2021 SEASON UPDATE', 'Sea of Thieves',
#        'Counter-Strike', 'Tales of Arise', 'Path of Exile', 'Soundpad',
#        'Cyberpunk 2077', 'Medieval Dynasty', 'Need foor Speed Heat',
#        'Phasmophobia', 'NBA 2k21', 'Eternal Return ', 'Shadowverse',
#        'Hunt: Showdown', 'Satisfactory', 'Geometry Dash',
#        'Total War: THREE KINGDOMS', 'Oxygen Not Included',
#        'Dyson Sphere Program', 'Battlefield 1', 'Dying Light ',
#        'Slay the Spire', 'The Sims 4', 'Divinity: Original Sin 2'],
#       dtype=object)

# %%
ID_list = monthly_players.URL.unique()

# %%
for i in range(0,len(ID_list)):
    ID_list[i] = ID_list[i].replace('https://steamcharts.com/app/', '')
ID_list
# Out:
# array(['730', '570', '578080', '1172470', '440', '271590', '1203220',
#        '431960', '252490', '1085660', '230410', '1454400', '359550',
#        '1263850', '218620', '346110', '381210', '289070', '1623660',
#        '304930', '105600', '236390', '394360', '1238810', '892970',
#        '444200', '221100', '594570', '322330', '227300', '252950', '4000',
#        '582010', '413150', '39210', '1254120', '292030', '1329410',
#        '294100', '1174180', '251570', '582660', '255710', '8930',
#        '787860', '489830', '281990', '306130', '550', '1293830', '236850',
#        '480', '813780', '1184370', '601510', '250900', '513710', '377160',
#        '427520', '261550', '1281930', '1644960', '960090', '291550',
#        '438100', '1097150', '107410', '1100600', '552990', '1313860',
#        '374320', '1158310', '835570', '275850', '1259970', '1172620',
#        '10', '740130', '238960', '629520', '1091500', '1129580',
#        '1222680', '739630', '1225330', '1049590', '453480', '594650',
#        '526870', '322170', '779340', '457140', '1366540', '1238840',
#        '239140', '646570', '1222670', '435150'], dtype=object)

# %%
# Strip the URL data off the app ID
url_list = monthly_players["URL"]
for i in range(0,len(url_list)):
    url_list[i] = url_list[i].replace('https://steamcharts.com/app/', '')
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_7864/1115660068.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   url_list[i] = url_list[i].replace('https://steamcharts.com/app/', '')

# %%
monthly_players = monthly_players.rename(columns={"URL": "APP"})
monthly_players
# Out:
#           Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0     September 2021    512350.92     268.96       +0.05%        942519
# 1        August 2021    512081.96    6014.60       +1.19%        802544
# 2          July 2021    506067.36  -43279.72       -7.88%        763523
# 3          June 2021    549347.08 -110541.81      -16.75%        929940
# 4           May 2021    659888.89  -63457.63       -8.77%       1087197
# ...              ...          ...        ...          ...           ...
# 5266   December 2016       192.03     -21.90      -10.24%           405
# 5267   November 2016       213.92    -134.68      -38.63%           537
# 5268    October 2016       348.60    -201.75      -36.66%          1031
# 5269  September 2016       550.36     543.26    +7654.89%          2836
# 5270     August 2016         7.10        NaN          NaN            18
#
#          APP        Date                         Game_Name
# 0        730  2021-09-01  Counter Strike: Global Offensive
# 1        730  2021-08-01  Counter Strike: Global Offensive
# 2        730  2021-07-01  Counter Strike: Global Offensive
# 3        730  2021-06-01  Counter Strike: Global Offensive
# 4        730  2021-05-01  Counter Strike: Global Offensive
# ...      ...         ...                               ...
# 5266  435150  2016-12-01          Divinity: Original Sin 2
# 5267  435150  2016-11-01          Divinity: Original Sin 2
# 5268  435150  2016-10-01          Divinity: Original Sin 2
# 5269  435150  2016-09-01          Divinity: Original Sin 2
# 5270  435150  2016-08-01          Divinity: Original Sin 2
#
# [5271 rows x 8 columns]

# %%
# split dataframe into relational dataframes
games = monthly_players[["APP", "Game_Name"]]
games = games.drop_duplicates().set_index("APP")
games
# Out:
#                                 Game_Name
# APP
# 730      Counter Strike: Global Offensive
# 570                                Dota 2
# 578080                PUBG: Battlegrounds
# 1172470                      Apex Legends
# 440                       Team Fortress 2
# ...                                   ...
# 1238840                     Battlefield 1
# 239140                       Dying Light
# 646570                     Slay the Spire
# 1222670                        The Sims 4
# 435150           Divinity: Original Sin 2
#
# [98 rows x 1 columns]

# %%
reduced_players = monthly_players[["Percent_Gain", "APP", "Date"]]
reduced_players
# Out:
#      Percent_Gain     APP        Date
# 0          +0.05%     730  2021-09-01
# 1          +1.19%     730  2021-08-01
# 2          -7.88%     730  2021-07-01
# 3         -16.75%     730  2021-06-01
# 4          -8.77%     730  2021-05-01
# ...           ...     ...         ...
# 5266      -10.24%  435150  2016-12-01
# 5267      -38.63%  435150  2016-11-01
# 5268      -36.66%  435150  2016-10-01
# 5269    +7654.89%  435150  2016-09-01
# 5270          NaN  435150  2016-08-01
#
# [5271 rows x 3 columns]

# %% [markdown]
# ## Remove bad rows

# %%
# Drop games with 1 or 2 rows; this is not enough data to extrapolate from, 
# as we will need to drop the first two months of a game's existence
game_id = reduced_players.APP.value_counts()
print(game_id)
clean_ID_list = []

for i in range(0,len(game_id)):
    if game_id[i] > 2:
        clean_ID_list.append(game_id.index[i])
    else:
        print(f"removing {games.loc[game_id.index[i]]}(app ID {game_id.index[i]}) due to having too few months of data")
        
len(clean_ID_list)
# Out:
# 730        111
# 550        111
# 570        111
# 440        111
# 4000       111
#           ...
# 1203220      2
# 740130       1
# 1644960      1
# 1454400      1
# 1184370      1
# Name: APP, Length: 98, dtype: int64
# removing Game_Name    MIR4
# Name: 1623660, dtype: object(app ID 1623660) due to having too few months of data
# removing Game_Name    Bless Unleashed
# Name: 1254120, dtype: object(app ID 1254120) due to having too few months of data
# removing Game_Name    NARAKA: BLADEPOINT
# Name: 1203220, dtype: object(app ID 1203220) due to having too few months of data
# removing Game_Name    Tales of Arise
# Name: 740130, dtype: object(app ID 740130) due to having too few months of data
# removing Game_Name    NBA 2k22
# Name: 1644960, dtype: object(app ID 1644960) due to having too few months of data
# removing Game_Name    Cookie Clicker
# Name: 1454400, dtype: object(app ID 1454400) due to having too few months of data
# removing Game_Name    Pathfinder: Wrath of Righteous
# Name: 1184370, dtype: object(app ID 1184370) due to having too few months of data
# 91

# %%
# drop bottom two rows of each app, as the initial 2 months feature unusable data (NaN, followed by extreme outlier due to percentage calculation)
temp_df =pd.DataFrame(columns = reduced_players.columns)

for ID in clean_ID_list:
    df = reduced_players[reduced_players.APP == ID]
    df = df.reset_index(drop=True)
    print(df)
    df = df.drop(len(df)-1)
    df = df.drop(len(df)-1)
    print(df)
    temp_df = pd.concat([temp_df, df], ignore_index=True)
reduced_players = temp_df
# Out:
#     Percent_Gain  APP        Date
# 0         +0.05%  730  2021-09-01
# 1         +1.19%  730  2021-08-01
# 2         -7.88%  730  2021-07-01
# 3        -16.75%  730  2021-06-01
# 4         -8.77%  730  2021-05-01
# ..           ...  ...         ...
# 106      +31.61%  730  2012-11-01
# 107      -32.88%  730  2012-10-01
# 108       +3.39%  730  2012-09-01
# 109    +1559.43%  730  2012-08-01
# 110          NaN  730  2012-07-01
#
# [111 rows x 3 columns]
#     Percent_Gain  APP        Date
# 0         +0.05%  730  2021-09-01
# 1         +1.19%  730  2021-08-01
# 2         -7.88%  730  2021-07-01
# 3        -16.75%  730  2021-06-01
# 4         -8.77%  730  2021-05-01
# ..           ...  ...         ...
# 104      +14.81%  730  2013-01-01
# 105       -0.39%  730  2012-12-01
# 106      +31.61%  730  2012-11-01
# 107      -32.88%  730  2012-10-01
# 108       +3.39%  730  2012-09-01
#
# [109 rows x 3 columns]
#     Percent_Gain  APP        Date
# 0        -14.13%  550  2021-09-01
# 1         -0.46%  550  2021-08-01
# 2        +20.23%  550  2021-07-01
# 3        -10.90%  550  2021-06-01
# 4        +21.26%  550  2021-05-01
# ..           ...  ...         ...
# 106       +5.25%  550  2012-11-01
# 107      +40.87%  550  2012-10-01
# 108      -22.81%  550  2012-09-01
# 109      -32.72%  550  2012-08-01
# 110          NaN  550  2012-07-01
#
# [111 rows x 3 columns]
#     Percent_Gain  APP        Date
# 0        -14.13%  550  2021-09-01
# 1         -0.46%  550  2021-08-01
# 2        +20.23%  550  2021-07-01
# 3        -10.90%  550  2021-06-01
# 4        +21.26%  550  2021-05-01
# ..           ...  ...         ...
# 104       +0.14%  550  2013-01-01
# 105       -0.14%  550  2012-12-01
# 106       +5.25%  550  2012-11-01
# 107      +40.87%  550  2012-10-01
# 108      -22.81%  550  2012-09-01
#
# [109 rows x 3 columns]
#     Percent_Gain  APP        Date
# 
# 6      -53.06%  1366540  2021-03-01
#   Percent_Gain     APP        Date
# 0      +90.40%  892970  2021-09-01
# 1       -6.28%  892970  2021-08-01
# 2       -8.48%  892970  2021-07-01
# 3      -42.11%  892970  2021-06-01
# 4      -49.70%  892970  2021-05-01
# 5      -61.12%  892970  2021-04-01
# 6      -15.15%  892970  2021-03-01
# 7          NaN  892970  2021-02-01
#   Percent_Gain     APP        Date
# 0      +90.40%  892970  2021-09-01
# 1       -6.28%  892970  2021-08-01
# 2       -8.48%  892970  2021-07-01
# 3      -42.11%  892970  2021-06-01
# 4      -49.70%  892970  2021-05-01
# 5      -61.12%  892970  2021-04-01
#   Percent_Gain      APP        Date
# 0       -3.43%  1293830  2021-09-01
# 1      -47.45%  1293830  2021-08-01
# 2      +68.25%  1293830  2021-07-01
# 3      +17.89%  1293830  2021-06-01
# 4      -36.69%  1293830  2021-05-01
# 5      +14.42%  1293830  2021-04-01
# 6          NaN  1293830  2021-03-01
#   Percent_Gain      APP        Date
# 0       -3.43%  1293830  2021-09-01
# 1      -47.45%  1293830  2021-08-01
# 2      +68.25%  1293830  2021-07-01
# 3      +17.89%  1293830  2021-06-01
# 4      -36.69%  1293830  2021-05-01

# %%
# reprint the cleaned up reduced_players
reduced_players

# nb: perhaps the above cleaning process could have been done in one step by simply catching and handling errors?
# Out:
#      Percent_Gain      APP        Date
# 0          +0.05%      730  2021-09-01
# 1          +1.19%      730  2021-08-01
# 2          -7.88%      730  2021-07-01
# 3         -16.75%      730  2021-06-01
# 4          -8.77%      730  2021-05-01
# ...           ...      ...         ...
# 5074       -3.43%  1293830  2021-09-01
# 5075      -47.45%  1293830  2021-08-01
# 5076      +68.25%  1293830  2021-07-01
# 5077      +17.89%  1293830  2021-06-01
# 5078      -36.69%  1293830  2021-05-01
#
# [5079 rows x 3 columns]

# %% [markdown]
# ## Fix Datatypes

# %%
# strip off the percent symbol and convert it into a float
percentages = reduced_players["Percent_Gain"]
for i in range(0, len(reduced_players)):
    try:
        reduced_players.loc[i, "Percent_Gain"] = float(reduced_players.loc[i, "Percent_Gain"].replace("%",""))
    except AttributeError as e:
        app = reduced_players.loc[i, "APP"]
        print(f"error on app id {app}")
        print(e)

print(reduced_players.dtypes)
# Out:
# Percent_Gain    object
# APP             object
# Date            object
# dtype: object

# %%
reduced_players
# Out:
#      Percent_Gain      APP        Date
# 0            0.05      730  2021-09-01
# 1            1.19      730  2021-08-01
# 2           -7.88      730  2021-07-01
# 3          -16.75      730  2021-06-01
# 4           -8.77      730  2021-05-01
# ...           ...      ...         ...
# 5074        -3.43  1293830  2021-09-01
# 5075       -47.45  1293830  2021-08-01
# 5076        68.25  1293830  2021-07-01
# 5077        17.89  1293830  2021-06-01
# 5078       -36.69  1293830  2021-05-01
#
# [5079 rows x 3 columns]

# %%
# check all percent values are now floats:
for i in range (0,len(reduced_players)):
    if(type(reduced_players.loc[i][0]) != float):
        print("non-float found")

# %%
# we can keep APP as a str as we don't want to be using it to make any predictions.

# %%
# convert 'Date' to true date-time format
for i in range (0,len(reduced_players)):
    reduced_players.loc[i][2] = pd.to_datetime(reduced_players.loc[i][2])

# %%
reduced_players
# Out:
#      Percent_Gain      APP                 Date
# 0            0.05      730  2021-09-01 00:00:00
# 1            1.19      730  2021-08-01 00:00:00
# 2           -7.88      730  2021-07-01 00:00:00
# 3          -16.75      730  2021-06-01 00:00:00
# 4           -8.77      730  2021-05-01 00:00:00
# ...           ...      ...                  ...
# 5074        -3.43  1293830  2021-09-01 00:00:00
# 5075       -47.45  1293830  2021-08-01 00:00:00
# 5076        68.25  1293830  2021-07-01 00:00:00
# 5077        17.89  1293830  2021-06-01 00:00:00
# 5078       -36.69  1293830  2021-05-01 00:00:00
#
# [5079 rows x 3 columns]

# %% [markdown]
# ## Read in news data

# %%
# this time, I am going to wrap the whole thing in a for loop, to do a separate call for each game.

Monthly_data_cleaned_joined = pd.DataFrame()

for app_no in clean_ID_list:
    print(f"new app:{app_no}")
    if (app_no == '480'):
        # UPDATE! quick hack:
        # skip app 480 - it is a secret test game and has no news feed.
        continue
    current_df = reduced_players[reduced_players.APP == app_no]
    current_df = current_df.reset_index(drop=True)
#     print(current_df)
    
    # build dataframe from json data and reduce to relevant columns

    # call for just one news item
    count = 1
    max_length = 1024
    api_url = f"http://api.steampowered.com/ISteamNews/GetNewsForApp/v0002/?appid={app_no}&count={count}&maxlength={max_length}&format=json"
    news_response = requests.get(api_url).json()

    # find out how many news items for this app, and then recall news items.
    count = news_response['appnews']['count']
    api_url = f"http://api.steampowered.com/ISteamNews/GetNewsForApp/v0002/?appid={app_no}&count={count}&maxlength={max_length}&format=json"
    news_response = requests.get(api_url).json()
    
    # new DF to store response
    newsDF = pd.DataFrame(columns=['Date', 'Label'])

    # get the date and label of each news item; we can ignore the actual text of the news item on this first approach.
    for item in (news_response['appnews']['newsitems']):
        # convert unix date to yyy-mm-dd
#         print(f"{pd.to_datetime(item['date'], unit='s')} {item['feedlabel']}")
        row = pd.DataFrame(data={'Date': [pd.to_datetime(item['date'], unit='s')], 'Label': [item['feedlabel']]})
        newsDF = pd.concat([newsDF, row])
    
    #reset the index and print out the important values from the dataframe
    newsDF = newsDF.reset_index(drop=True)
#     print(newsDF)
    print(newsDF.nunique())
    print(newsDF.Label.value_counts())
    
    # add new label columns (if any) to the dataframe
    labels_index = newsDF.Label.value_counts().index
    for column in labels_index:
        current_df[column] = 0
    current_df
#     print(current_df)
    
    # bin news feed into monthly groups
    for i in range(0, len(current_df)):
        # set start and end dates for the current month
        start_date = current_df.loc[i, 'Date']
        end_date = start_date + relativedelta(months = 1)
#         print(f"{start_date}, {end_date}")
        #identify rows from the newsDF that fall into that category
        for j in range(0, len(newsDF)):
            if ((newsDF.loc[j, 'Date'] >= start_date) & (newsDF.loc[j, 'Date'] < end_date)):
                # find the relevant label and increment that column on the overall grid
                feed_type = newsDF.loc[j, 'Label']
#                 print(feed_type)
                current_df.loc[i, feed_type] += 1
    Monthly_data_cleaned_joined = pd.concat([Monthly_data_cleaned_joined, current_df], ignore_index=True)
# Out:
# new app:730
# Date     1265
# Label      12
# dtype: int64
# PC Gamer                   434
# Rock, Paper, Shotgun       259
# The Loadout                150
# Community Announcements    138
# SteamDB                    127
# PCGamesN                    79
# Product Update              72
# Eurogamer                   23
# GamingOnLinux               15
# Announcement                 9
# Kotaku                       6
# Product Release              3
# Name: Label, dtype: int64
# new app:550
# Date     812
# Label     13
# dtype: int64
# L4D Blog                   272
# Community Announcements    268
# Product Update             165
# PC Gamer                    82
# Kotaku                      65
# Rock, Paper, Shotgun        50
# Shacknews                   44
# Eurogamer                   18
# Announcement                14
# GamingOnLinux                5
# PCGamesN                     3
# Product Release              2
# VG247                        1
# Name: Label, dtype: int64
# new app:570
# Date     2700
# Label      16
# dtype: int64
# Product Update             695
# PC Gamer                   649
# Community Announcements    585
# SteamDB                    386
# Rock, Paper, Shotgun       319
# PCGamesN                    77
# The Loadout                 73
# Dota Beta Blog              58
# Dota Blog                   34
# Kotaku                      30
# Eurogamer                   27
# GamingOnLinux               18
# Product Release              4
# Announcement                 4
# Press Release                2
# Client Update                1
# Name: Label, dtype: int64
# new app:440
# Date     2502
# Label      15
# dtype: int64
# TF2 Blog                   1179
# Product Update              632
# Community Announcements     496
# PC Gamer                    351
# Kotaku                      216
# Rock, Paper, Shotgun        160
# Shacknews                    90
# SteamDB                      42
# Eurogamer                    37
# PCGamesN                     13
# GamingOnLinux                 8
# Announcement                  5
# The Loadout                   2
# Product Release               2
# Press Release                 2
# Name: Label, dtype: int64
# new app:4000
# Date     243
# Label      8
# dtype: int64
# Community Announcements    167
# Product Update              51
# PC Gamer                    33
# Rock, Paper, Shotgun        25
# Announcement                 8
# Shacknews                    6
# Kotaku                       6
# VG247                        1
# Name: Label, dtype: int64
# new app:480
# new app:10
# Date     237
# Label      8
# dtype: int64
# PC Gamer                   118
# Community Announcements     65
# Kotaku                      43
# Rock, Paper, Shotgun        37
# Eurogamer                    5
# Product Update               2
# GamingOnLinux                1
# Shacknews                    1
# Name: Label, dtype: int64
# new app:8930
# Date     265
# Label      9
# dtype: int64
# PC Gamer                   98
# Rock, Paper, Shotgun       52
# Shacknews                  40
# Community Announcements    37
# Product Update             25
# Announcement               14
# Product Release             8
# Eurogamer                   5
# PCGamesN                    4
# Name: Label, dtype: int64
# new app:105600
# Date     244
# Label     10
# dtype: int64
# Community Announcements    69
# Rock, Paper, Shotgun       60
# PC Gamer                   58
# PCGamesN                   26
# GamingOnLinux              11
# Announcement               11
# Product Update             10
# Kotaku                      7
# Eurogamer                   4
# Product Release             2
# Name: Label, dtype: int64
# new app:218620
# Date     924
# Label      6
# dtype: int64
# Community Announcements    1584
# Announcement                 15
# Eurogamer                    10
# Product Release              10
# PCGamesN                      1
# Product Update                1
# Name: Label, dtype: int64
# new app:221100
# Date     392
# Label      9
# dtype: int64
# Community Announcements    380
# PC Gamer                    83
# Rock, Paper, Shotgun        61
# Eurogamer                   10
# PCGamesN                     6
# The Loadout                  2
# Product Release              2
# SteamDB                      1
# Announcement                 1
# Name: Label, dtype: int64
# new app:227300
# Date     730
# Label     10
# dtype: int64
# Community Announcements    826
# Rock, Paper, Shotgun        70
# PC Gamer                    49
# PCGamesN                    32
# GamingOnLinux                8
# Announcement                 6
# Product Release              4
# Eurogamer                    3
# Shacknews                    2
# Product Update               1
# Name: Label, dtype: int64
# new app:230410
# Date     934
# Label     10
# dtype: int64
# Community Announcements    923
# PC Gamer                   125
# Rock, Paper, Shotgun        88
# PCGamesN                    53
# Eurogamer                   36
# VG247                        8
# Product Release              3
# Announcement                 2
# Shacknews                    2
# Product Update               1
# Name: Label, dtype: int64
# new app:107410
# Date     884
# Label      9
# dtype: int64
# Community Announcements    1082
# PC Gamer                    146
# Rock, Paper, Shotgun         67
# Announcement                 11
# PCGamesN                      9
# Product Update                9
# Product Release               5
# Eurogamer                     2
# Wargamer.com                  2
# Name: Label, dtype: int64
# new app:236850
# Date     576
# Label     10
# dtype: int64
# Community Announcements    645
# Rock, Paper, Shotgun        54
# PCGamesN                    17
# Announcement                12
# Strategy Gamer              10
# Product Release              9
# PC Gamer                     8
# GamingOnLinux                5
# Eurogamer                    5
# Shacknews                    3
# Name: Label, dtype: int64
# new app:236390
# Date     2480
# Label       9
# dtype: int64
# Community Announcements    3454
# Rock, Paper, Shotgun         23
# PCGamesN                     12
# PC Gamer                     11
# GamingOnLinux                 9
# Product Release               2
# VG247                         1
# Eurogamer                     1
# Announcement                  1
# Name: Label, dtype: int64
# new app:238960
# Date     2634
# Label       7
# dtype: int64
# Community Announcements    3213
# Rock, Paper, Shotgun         63
# PC Gamer                     59
# PCGamesN                     20
# Eurogamer                     7
# Product Update                2
# Product Release               1
# Name: Label, dtype: int64
# new app:252490
# Date     685
# Label     10
# dtype: int64
# Community Announcements    879
# PC Gamer                    73
# PCGamesN                    45
# Rock, Paper, Shotgun        34
# SteamDB                     19
# Eurogamer                    9
# Shacknews                    6
# Gamemag.ru                   3
# GamingOnLinux                2
# Product Release              2
# Name: Label, dtype: int64
# new app:251570
# Date     230
# Label      5
# dtype: int64
# Community Announcements    339
# GamingOnLinux                2
# PC Gamer                     2
# Announcement                 2
# Product Release              1
# Name: Label, dtype: int64
# new app:39210
# Date     460
# Label      5
# dtype: int64
# Community Announcements    265
# PCGamesN                   188
# Rock, Paper, Shotgun        47
# VG247                        4
# Product Release              1
# Name: Label, dtype: int64
# new app:291550
# Date     493
# Label      5
# dtype: int64
# Community Announcements    707
# Rock, Paper, Shotgun         7
# PC Gamer                     4
# Eurogamer                    1
# Product Release              1
# Name: Label, dtype: int64
# new app:304930
# Date     405
# Label      5
# dtype: int64
# Community Announcements    681
# PC Gamer                     5
# Rock, Paper, Shotgun         3
# VG247                        1
# Product Release              1
# Name: Label, dtype: int64
# new app:306130
# Date     432
# Label      7
# dtype: int64
# Community Announcements    303
# PC Gamer                    68
# Rock, Paper, Shotgun        57
# PCGamesN                    23
# Eurogamer                   15
# Product Release             11
# VG247                        3
# Name: Label, dtype: int64
# new app:250900
# Date     109
# Label      5
# dtype: int64
# Community Announcements    57
# Rock, Paper, Shotgun       49
# Product Release             5
# Announcement                4
# Eurogamer                   2
# Name: Label, dtype: int64
# new app:322170
# Date     27
# Label     3
# dtype: int64
# Community Announcements    47
# Rock, Paper, Shotgun        1
# Announcement                1
# Name: Label, dtype: int64
# new app:322330
# Date     386
# Label      5
# dtype: int64
# Community Announcements    541
# GamingOnLinux               10
# Announcement                 4
# Rock, Paper, Shotgun         3
# Product Release              1
# Name: Label, dtype: int64
# new app:239140
# Date     291
# Label      8
# dtype: int64
# Community Announcements    262
# Rock, Paper, Shotgun        48
# Announcement                11
# GamingOnLinux                9
# VG247                        6
# Eurogamer                    5
# Product Release              4
# PCGamesN                     2
# Name: Label, dtype: int64
# new app:255710
# Date     552
# Label      8
# dtype: int64
# Community Announcements    392
# PC Gamer                    96
# Rock, Paper, Shotgun        90
# PCGamesN                    21
# Eurogamer                   11
# Announcement                 8
# Product Release              5
# GamingOnLinux                4
# Name: Label, dtype: int64
# new app:271590
# Date     1113
# Label      10
# dtype: int64
# PC Gamer                   407
# Rock, Paper, Shotgun       302
# Community Announcements    198
# PCGamesN                   182
# Eurogamer                   46
# The Loadout                 23
# VG247                       22
# SteamDB                     21
# Announcement                 9
# Product Release              1
# Name: Label, dtype: int64
# new app:346110
# Date     678
# Label     11
# dtype: int64
# Community Announcements    641
# PC Gamer                   111
# Rock, Paper, Shotgun        96
# PCGamesN                    18
# Eurogamer                   13
# Product Release             10
# SteamDB                      3
# GamingOnLinux                2
# Announcement                 2
# VG247                        1
# Product Update               1
# Name: Label, dtype: int64
# new app:292030
# Date     668
# Label      8
# dtype: int64
# PC Gamer                   252
# Rock, Paper, Shotgun       228
# Community Announcements     71
# PCGamesN                    63
# Eurogamer                   62
# VG247                       12
# Product Release              4
# Announcement                 2
# Name: Label, dtype: int64
# new app:252950
# Date     925
# Label     10
# dtype: int64
# Community Announcements    720
# PC Gamer                   178
# Rock, Paper, Shotgun       137
# The Loadout                 61
# Eurogamer                   31
# PCGamesN                    12
# VG247                        4
# Announcement                 4
# Product Release              3
# Product Update               1
# Name: Label, dtype: int64
# new app:377160
# Date     680
# Label      7
# dtype: int64
# PC Gamer                   299
# Rock, Paper, Shotgun       256
# Community Announcements     69
# PCGamesN                    48
# Eurogamer                   26
# Product Release             16
# VG247                        2
# Name: Label, dtype: int64
# new app:413150
# Date     280
# Label      9
# dtype: int64
# PC Gamer                   108
# PCGamesN                    60
# Rock, Paper, Shotgun        56
# Community Announcements     47
# Eurogamer                   19
# GamingOnLinux                5
# SteamDB                      1
# Announcement                 1
# Product Release              1
# Name: Label, dtype: int64
# new app:359550
# Date     1070
# Label       9
# dtype: int64
# Community Announcements    549
# Rock, Paper, Shotgun       227
# PC Gamer                   210
# PCGamesN                   150
# The Loadout                 84
# Announcement                 7
# Product Release              2
# Shacknews                    1
# Product Update               1
# Name: Label, dtype: int64
# new app:427520
# Date     552
# Label      6
# dtype: int64
# Community Announcements    766
# Rock, Paper, Shotgun        14
# PCGamesN                     6
# GamingOnLinux                4
# Eurogamer                    4
# Strategy Gamer               1
# Name: Label, dtype: int64
# new app:281990
# Date     685
# Label      9
# dtype: int64
# Community Announcements    570
# Rock, Paper, Shotgun       118
# PC Gamer                    74
# PCGamesN                    32
# GamingOnLinux               23
# Strategy Gamer              17
# Eurogamer                   10
# Announcement                 5
# Product Release              1
# Name: Label, dtype: int64
# new app:394360
# Date     448
# Label      9
# dtype: int64
# Community Announcements    455
# Rock, Paper, Shotgun        37
# PCGamesN                    31
# Strategy Gamer              21
# GamingOnLinux                8
# Wargamer.com                 8
# Announcement                 3
# Eurogamer                    1
# Product Release              1
# Name: Label, dtype: int64
# new app:374320
# Date     230
# Label      7
# dtype: int64
# PC Gamer                   102
# Community Announcements     71
# Rock, Paper, Shotgun        69
# Eurogamer                   10
# PCGamesN                     9
# Product Release              2
# Announcement                 1
# Name: Label, dtype: int64
# new app:294100
# Date     151
# Label      8
# dtype: int64
# Community Announcements    122
# PC Gamer                    18
# Rock, Paper, Shotgun        18
# GamingOnLinux                6
# PCGamesN                     5
# Eurogamer                    4
# Strategy Gamer               2
# Product Release              2
# Name: Label, dtype: int64
# new app:457140
# Date     190
# Label      7
# dtype: int64
# Community Announcements    171
# Rock, Paper, Shotgun        32
# GamingOnLinux                9
# PC Gamer                     7
# Eurogamer                    3
# Product Release              3
# Announcement                 2
# Name: Label, dtype: int64
# new app:381210
# Date     547
# Label      9
# dtype: int64
# Community Announcements    626
# Rock, Paper, Shotgun        49
# PC Gamer                    31
# PCGamesN                    18
# Eurogamer                   12
# The Loadout                 10
# VG247                        8
# Shacknews                    2
# Announcement                 2
# Name: Label, dtype: int64
# new app:275850
# Date     524
# Label     13
# dtype: int64
# PC Gamer                   173
# Rock, Paper, Shotgun       154
# Community Announcements    112
# Eurogamer                   47
# PCGamesN                    22
# Gamemag.ru                  15
# VG247                       10
# SteamDB                      9
# Announcement                 3
# GamingOnLinux                2
# Product Release              2
# pressakey.com                1
# Shacknews                    1
# Name: Label, dtype: int64
# new app:435150
# Date     294
# Label      7
# dtype: int64
# Community Announcements    179
# Rock, Paper, Shotgun       102
# PC Gamer                    64
# Eurogamer                   12
# PCGamesN                     4
# Announcement                 2
# Product Release              1
# Name: Label, dtype: int64
# new app:431960
# Date     68
# Label     3
# dtype: int64
# Community Announcements    92
# Rock, Paper, Shotgun        4
# SteamDB                     1
# Name: Label, dtype: int64
# new app:489830
# Date     219
# Label      7
# dtype: int64
# PC Gamer                   72
# Rock, Paper, Shotgun       66
# Eurogamer                  41
# Community Announcements    31
# Gamemag.ru                 13
# PCGamesN                   10
# Product Release             5
# Name: Label, dtype: int64
# new app:453480
# Date     15
# Label     3
# dtype: int64
# Community Announcements    12
# Rock, Paper, Shotgun        5
# PC Gamer                    4
# Name: Label, dtype: int64
# new app:444200
# Date     343
# Label      2
# dtype: int64
# Community Announcements    408
# Product Release              2
# Name: Label, dtype: int64
# new app:289070
# Date     497
# Label     10
# dtype: int64
# Community Announcements    237
# Rock, Paper, Shotgun       109
# PC Gamer                    86
# PCGamesN                    59
# Strategy Gamer              43
# GamingOnLinux               17
# Eurogamer                   17
# Announcement                 5
# pressakey.com                1
# Product Release              1
# Name: Label, dtype: int64
# new app:438100
# Date     99
# Label     3
# dtype: int64
# Community Announcements    123
# Rock, Paper, Shotgun         1
# PC Gamer                     1
# Name: Label, dtype: int64
# new app:578080
# Date     1633
# Label      10
# dtype: int64
# Community Announcements    596
# Rock, Paper, Shotgun       420
# PC Gamer                   388
# Eurogamer                  135
# PCGamesN                    99
# The Loadout                 57
# SteamDB                      9
# VG247                        4
# Product Release              2
# Shacknews                    1
# Name: Label, dtype: int64
# new app:594570
# Date     531
# Label      9
# dtype: int64
# Community Announcements    419
# Rock, Paper, Shotgun        76
# PC Gamer                    65
# PCGamesN                    29
# Strategy Gamer              26
# Eurogamer                   18
# GamingOnLinux                6
# Announcement                 2
# Product Release              1
# Name: Label, dtype: int64
# new app:582660
# Date     743
# Label      6
# dtype: int64
# Community Announcements    868
# Announcement                 4
# PCGamesN                     3
# Rock, Paper, Shotgun         3
# Eurogamer                    1
# Product Release              1
# Name: Label, dtype: int64
# new app:646570
# Date     193
# Label      8
# dtype: int64
# Community Announcements    120
# Rock, Paper, Shotgun        52
# PC Gamer                    29
# Eurogamer                   11
# GamingOnLinux                3
# PCGamesN                     2
# VG247                        1
# Announcement                 1
# Name: Label, dtype: int64
# new app:513710
# Date     355
# Label      5
# dtype: int64
# Community Announcements    335
# PC Gamer                    25
# Rock, Paper, Shotgun        17
# Eurogamer                    3
# Product Release              1
# Name: Label, dtype: int64
# new app:629520
# Date     45
# Label     1
# dtype: int64
# Community Announcements    64
# Name: Label, dtype: int64
# new app:594650
# Date     812
# Label      9
# dtype: int64
# Community Announcements    844
# PC Gamer                    46
# Rock, Paper, Shotgun        26
# Eurogamer                    8
# Gamemag.ru                   3
# Announcement                 2
# VG247                        1
# pressakey.com                1
# Product Release              1
# Name: Label, dtype: int64
# new app:552990
# Date     773
# Label      5
# dtype: int64
# Community Announcements    801
# Gamemag.ru                   7
# PCGamesN                     6
# Rock, Paper, Shotgun         3
# Product Release              1
# Name: Label, dtype: int64
# new app:601510
# Date     57
# Label     4
# dtype: int64
# Community Announcements    84
# Product Release             2
# Strategy Gamer              1
# PC Gamer                    1
# Name: Label, dtype: int64
# new app:582010
# Date     549
# Label      8
# dtype: int64
# Community Announcements    217
# Rock, Paper, Shotgun       186
# PC Gamer                    79
# Eurogamer                   51
# PCGamesN                    13
# VG247                        3
# Announcement                 1
# Product Release              1
# Name: Label, dtype: int64
# new app:787860
# Date     61
# Label     6
# dtype: int64
# Community Announcements    35
# Rock, Paper, Shotgun       14
# PC Gamer                    8
# Eurogamer                   2
# The Loadout                 1
# Announcement                1
# Name: Label, dtype: int64
# new app:960090
# Date     38
# Label     3
# dtype: int64
# Community Announcements    35
# PCGamesN                    2
# Announcement                1
# Name: Label, dtype: int64
# new app:779340
# Date     341
# Label      9
# dtype: int64
# Community Announcements    238
# Rock, Paper, Shotgun        47
# Eurogamer                   15
# PC Gamer                    14
# PCGamesN                    12
# Strategy Gamer               9
# GamingOnLinux                4
# Announcement                 3
# Product Release              1
# Name: Label, dtype: int64
# new app:835570
# Date     858
# Label      1
# dtype: int64
# Community Announcements    858
# Name: Label, dtype: int64
# new app:1085660
# Date     726
# Label      9
# dtype: int64
# PC Gamer                   276
# Community Announcements    171
# Rock, Paper, Shotgun       136
# Eurogamer                   68
# VG247                       42
# Gamemag.ru                  35
# Shacknews                    1
# pressakey.com                1
# Product Release              1
# Name: Label, dtype: int64
# new app:1100600
# Date     80
# Label     5
# dtype: int64
# Community Announcements    58
# Rock, Paper, Shotgun       13
# Eurogamer                   6
# PCGamesN                    2
# Product Release             1
# Name: Label, dtype: int64
# new app:813780
# Date     311
# Label      8
# dtype: int64
# Community Announcements    266
# Rock, Paper, Shotgun        25
# Strategy Gamer               6
# PC Gamer                     5
# Eurogamer                    5
# PCGamesN                     4
# The Loadout                  1
# pressakey.com                1
# Name: Label, dtype: int64
# new app:1174180
# Date     78
# Label     6
# dtype: int64
# SteamDB                    27
# Rock, Paper, Shotgun       27
# Eurogamer                  18
# Community Announcements     6
# Shacknews                   2
# The Loadout                 1
# Name: Label, dtype: int64
# new app:261550
# Date     414
# Label      4
# dtype: int64
# Community Announcements    346
# Rock, Paper, Shotgun        68
# PC Gamer                    36
# PCGamesN                     6
# Name: Label, dtype: int64
# new app:1281930
# Date     13
# Label     1
# dtype: int64
# Community Announcements    13
# Name: Label, dtype: int64
# new app:1238810
# Date     23
# Label     4
# dtype: int64
# Community Announcements    11
# SteamDB                     9
# Eurogamer                   2
# pressakey.com               1
# Name: Label, dtype: int64
# new app:526870
# Date     164
# Label      5
# dtype: int64
# Community Announcements    132
# Rock, Paper, Shotgun        21
# Eurogamer                    6
# PC Gamer                     4
# SteamDB                      1
# Name: Label, dtype: int64
# new app:1222670
# Date     136
# Label      4
# dtype: int64
# Community Announcements    69
# Rock, Paper, Shotgun       50
# VG247                      11
# Eurogamer                   8
# Name: Label, dtype: int64
# new app:1172620
# Date     159
# Label      5
# dtype: int64
# Community Announcements    100
# SteamDB                     23
# Eurogamer                   20
# Rock, Paper, Shotgun        16
# Shacknews                    1
# Name: Label, dtype: int64
# new app:1222680
# Date     7
# Label    2
# dtype: int64
# Eurogamer                  4
# Community Announcements    3
# Name: Label, dtype: int64
# new app:1238840
# Date     6
# Label    2
# dtype: int64
# Community Announcements    5
# SteamDB                    1
# Name: Label, dtype: int64
# new app:1329410
# Date     29
# Label     1
# dtype: int64
# Community Announcements    29
# Name: Label, dtype: int64
# new app:1097150
# Date     155
# Label      7
# dtype: int64
# Community Announcements    58
# PCGamesN                   42
# Eurogamer                  24
# PC Gamer                   17
# SteamDB                     7
# Shacknews                   5
# Rock, Paper, Shotgun        2
# Name: Label, dtype: int64
# new app:1129580
# Date     155
# Label      3
# dtype: int64
# Community Announcements    152
# SteamDB                      2
# PC Gamer                     1
# Name: Label, dtype: int64
# new app:1225330
# Date     25
# Label     4
# dtype: int64
# Community Announcements    13
# Gamemag.ru                 10
# PCGamesN                    1
# Eurogamer                   1
# Name: Label, dtype: int64
# new app:1158310
# Date     409
# Label      9
# dtype: int64
# Community Announcements    273
# PCGamesN                    52
# Strategy Gamer              23
# Rock, Paper, Shotgun        21
# GamingOnLinux               16
# Eurogamer                   15
# Gamemag.ru                   9
# SteamDB                      1
# pressakey.com                1
# Name: Label, dtype: int64
# new app:1259970
# Date     38
# Label     2
# dtype: int64
# Community Announcements    38
# PCGamesN                    1
# Name: Label, dtype: int64
# new app:739630
# Date     173
# Label      8
# dtype: int64
# Community Announcements    65
# PCGamesN                   54
# SteamDB                    20
# Rock, Paper, Shotgun       15
# PC Gamer                   12
# Eurogamer                   5
# VG247                       3
# Shacknews                   1
# Name: Label, dtype: int64
# new app:1049590
# Date     1117
# Label       1
# dtype: int64
# Community Announcements    1117
# Name: Label, dtype: int64
# new app:1313860
# Date     193
# Label      6
# dtype: int64
# Community Announcements    94
# The Loadout                46
# Gamemag.ru                 39
# PC Gamer                    5
# Rock, Paper, Shotgun        5
# SteamDB                     4
# Name: Label, dtype: int64
# new app:1172470
# Date     619
# Label      8
# dtype: int64
# The Loadout                242
# Community Announcements    142
# Rock, Paper, Shotgun        95
# Eurogamer                   52
# Gamemag.ru                  46
# VG247                       45
# GamingOnLinux                1
# pressakey.com                1
# Name: Label, dtype: int64
# new app:1263850
# Date     79
# Label     6
# dtype: int64
# Community Announcements    52
# PCGamesN                   10
# Eurogamer                   8
# SteamDB                     6
# Rock, Paper, Shotgun        2
# VG247                       1
# Name: Label, dtype: int64
# new app:1091500
# Date     921
# Label     10
# dtype: int64
# Gamemag.ru                 362
# Rock, Paper, Shotgun       241
# PC Gamer                   157
# Eurogamer                   66
# Community Announcements     55
# SteamDB                     31
# VG247                       23
# Shacknews                   11
# pressakey.com                6
# Announcement                 1
# Name: Label, dtype: int64
# new app:1366540
# Date     103
# Label      5
# dtype: int64
# Community Announcements    89
# PCGamesN                    8
# SteamDB                     4
# Rock, Paper, Shotgun        3
# Strategy Gamer              1
# Name: Label, dtype: int64
# new app:892970
# Date     173
# Label      7
# dtype: int64
# Community Announcements    62
# GamingOnLinux              38
# Eurogamer                  27
# Rock, Paper, Shotgun       24
# SteamDB                    14
# VG247                       7
# Shacknews                   2
# Name: Label, dtype: int64
# new app:1293830
# Date     23
# Label     3
# dtype: int64
# Community Announcements    15
# SteamDB                     7
# Eurogamer                   1
# Name: Label, dtype: int64

# %%
Monthly_data_cleaned_joined = Monthly_data_cleaned_joined.fillna(0)

# %%
# add binary target: positive or negative change
# 1 for positive, 0 for negative
Monthly_data_cleaned_joined["Binary_outcome"] = 0
Monthly_data_cleaned_joined

# %%
for i in range (0, len(Monthly_data_cleaned_joined)):
    if (Monthly_data_cleaned_joined.loc[i, 'Percent_Gain'] > 0):
        Monthly_data_cleaned_joined.loc[i, 'Binary_outcome'] = 1
    elif (Monthly_data_cleaned_joined.loc[i, 'Percent_Gain'] < 0):
        Monthly_data_cleaned_joined.loc[i, 'Binary_outcome'] = 0
    else:
        print("this should never be printed; true 0 found")

Monthly_data_cleaned_joined

# %% [markdown]
# # Machine Learning

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

path = "Resources/myopia.csv"
from pathlib import Path


from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf

# %% [markdown]
# ### supervised

# %%
# drop non-numerical data
Monthly_data_cleaned_joined = Monthly_data_cleaned_joined.drop(columns=['APP', 'Date', 'Percent_Gain'])

# %%
# make the choice of randomiser explicit:
sample_hold = 42

# %%
Monthly_data_cleaned_joined.shape

# %%
# Split the data into X_train, X_test, y_train, y_test
y = Monthly_data_cleaned_joined['Binary_outcome']

X = Monthly_data_cleaned_joined.drop(columns=['Binary_outcome'])


print("Shape: ", X.shape, y.shape)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=sample_hold)

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
Percent_Gain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7080/356647318.py in <module>
# ----> 1 scaler = StandardScaler().fit(X_train)
#       2 X_train_scaled = scaler.transform(X_train)
#       3 X_test_scaled = scaler.transform(X_test)
#       4 Percent_Gain
#       5
#
# NameError: name 'StandardScaler' is not defined

# %%
# Train a Logistic Regression model print the model score
classifier = LogisticRegression()
classifier.fit(X_train_scaled, y_train)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")

# %%
target_names = ["0", "1"]

# %%
clf = RandomForestClassifier(random_state=sample_hold).fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=target_names))
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')

# %% [markdown]
# ### unsupervised

# %%
Monthly_data_cleaned_joined.shape

# %%
Monthly_data_cleaned_joined.describe()

# %%
pd.plotting.scatter_matrix(Monthly_data_cleaned_joined, c=Monthly_data_cleaned_joined["Binary_outcome"], figsize=(16,16))
plt.savefig("1.png", format="png")

# %%
Monthly_data_cleaned_joined_unsuper = Monthly_data_cleaned_joined.drop(columns=["Binary_outcome"])
Monthly_data_cleaned_joined_unsuper

# %%
scaler = StandardScaler()


X = pd.DataFrame(scaler.fit_transform(X))
X

# %%
# Initialize PCA model for 90% explained variance
pca = PCA(n_components=0.9)

# Get two principal components for the data.
pcaX = pd.DataFrame(pca.fit_transform(X))
pcaX

# %%
tsne = TSNE(learning_rate=250)
tsne_features = tsne.fit_transform(pcaX)
TSNE_DF = pd.DataFrame(tsne_features)
TSNE_DF = TSNE_DF.rename(columns={0: "X", 1: "Y"})

TSNE_DF

# %%
plt.scatter(TSNE_DF.X, TSNE_DF.Y)

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(TSNE_DF)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for Myopia')
plt.show()

# %%
def get_clusters(k, data):
    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Train the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["class"] = model.labels_

    return data

# %%
clusters = get_clusters(4, TSNE_DF)

# %%
clusters

# %%
plt.scatter(x=clusters.X, y=clusters.Y, c=clusters["class"])

# %%
plt.scatter(TSNE_DF.X, TSNE_DF.Y, c=Monthly_data_cleaned_joined.Binary_outcome)

# %% [markdown]
# ### artificial neural network

# %%
input_dimensions=X.shape[1]
input_dimensions

# %%
X

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=input_dimensions))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=5),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    overwrite=True,
    max_epochs=20,
    hyperband_iterations=2,)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))

# %% [markdown]
# ### Search has not yielded anything higher than 55% accuracy.
# I will now experiment with dropping more columns from the data.
